# %%
import pandas as pd
df=pd.read_csv("Assessment.csv")
df.head()
# Out:
#                            Time  Gender Marital_Status  \
# 0  2019/02/12 11:08:15 AM GMT+2    Male        Married
# 1  2019/02/12 11:29:16 AM GMT+2    Male         Single
# 2  2019/02/12 11:32:16 AM GMT+2  Female         Single
# 3  2019/02/12 11:33:26 AM GMT+2    Male         Single
# 4  2019/02/12 11:34:44 AM GMT+2    Male        Married
#
#                           Household     Education  \
# 0  Immediate Family;Extended family      Tertiary
# 1                             Alone  Professional
# 2                        Sibling(s)  Professional
# 3                              Self      Tertiary
# 4                  Immediate Family  Professional
#
#                                           Movie_type Age_range Country_Origin  \
# 0                            Documentaries;Religious     31-35       Zimbabwe
# 1  Documentaries;Religious;Sci-fi;comedy;Romance;...     31-35       Zimbabwe
# 2                       Sci-fi;comedy;Romance;Action     21-25       zimbabwe
# 3                       Sci-fi;comedy;Romance;Action     31-35       Zimbabwe
# 4                                          Religious     31-35       Zimbabwe
#
#   Town_city_province      Current_staying  ...  Location_descr  \
# 0          Goromonzi             Chinhoyi  ...  Medium Density
# 1             Harare               Harare  ...  Medium Density
# 2             harare  prospect waterfalls  ...  Medium Density
# 3           Chipinge               Harare  ...     Low Density
# 4             Harare        Budiriro CABS  ...    High Density
#
#                 Expertise Income_range                Device_model  \
# 0                      IT  1001-10 000                     Nokia 5
# 1  information technology    101-1 000        laptop:thinkpad p51s
# 2                    data    101-1 000                          hp
# 3  Information Technology    101-1 000  Laptop:HP EliteBook 830 G5
# 4      System development  1001-10 000                    iPhone 6
#
#                          Sport  \
# 0            Atheletics;Soccer
# 1                       Others
# 2                   Atheletics
# 3  Soccer;Rugby;Tennis;Cricket
# 4                       Soccer
#
#                                           Technology  \
# 0  Information Technology;Agriculture;Artificial ...
# 1  Information Technology;Sensors;Transport;Appli...
# 2       Information Technology;Entertainment & Media
# 3                             Information Technology
# 4                             Information Technology
#
#                                                 News  \
# 0  hard news;feature news;Lifestyle/entertainment...
# 1  feature news;Lifestyle/entertainment;Profiles;...
# 2                  hard news;Lifestyle/entertainment
# 3  sport news;feature news;Investigative News;Tec...
# 4                                         sport news
#
#                                                Music  \
# 0                                   Gospel/religious
# 1  Gospel/religious;pop;rock;jazz;Rnb;Dance Hall;...
# 2    Gospel/religious;pop;rock;Rnb;Dance Hall;Reggae
# 3           sungura;jazz;Rnb;Dance Hall;Reggae;House
# 4                                   Gospel/religious
#
#                                              Hobbies  \
# 0                        reading;singing;watching TV
# 1                       reading;e-gaming;watching TV
# 2  Cooking;Mountain climbing;reading;fishing;e-ga...
# 3                               sporting;watching TV
# 4                                  Mountain climbing
#
#                                                 Food
# 0       legumes;Edible plants;Dairy products;Seafood
# 1  Baked goods;Breads;Dairy products;Eggs;Meat;Ce...
# 2  legumes;Edible plants;Baked goods;Breads;Dairy...
# 3                                               Meat
# 4                                               Meat
#
# [5 rows x 28 columns]

# %%
df=df.iloc[:,1:]

# %%
df['Country_Origin']=df['Country_Origin'].str.lower()
df['Town_city_province']=df['Town_city_province'].str.lower()
df['Current_staying']=df['Current_staying'].str.lower()
df['Language']=df['Language'].str.lower()
df['Expertise']=df['Expertise'].str.lower()
df['Device_model']=df['Device_model'].str.lower()
df['Household']=df['Household'].str.lower()
df['Movie_type']=df['Movie_type'].str.lower()
df['Expertise']=df['Expertise'].str.lower()
dat=df

# %%
dat.head()
# Out:
#    Gender Marital_Status                         Household     Education  \
# 0    Male        Married  immediate family;extended family      Tertiary
# 1    Male         Single                             alone  Professional
# 2  Female         Single                        sibling(s)  Professional
# 3    Male         Single                              self      Tertiary
# 4    Male        Married                  immediate family  Professional
#
#                                           Movie_type Age_range Country_Origin  \
# 0                            documentaries;religious     31-35       zimbabwe
# 1  documentaries;religious;sci-fi;comedy;romance;...     31-35       zimbabwe
# 2                       sci-fi;comedy;romance;action     21-25       zimbabwe
# 3                       sci-fi;comedy;romance;action     31-35       zimbabwe
# 4                                          religious     31-35       zimbabwe
#
#   Town_city_province      Current_staying                 Language  ...  \
# 0          goromonzi             chinhoyi            english,shona  ...
# 1             harare               harare  english, ndebele, shona  ...
# 2             harare  prospect waterfalls           english,shonja  ...
# 3           chipinge               harare           english, shona  ...
# 4             harare        budiriro cabs                  english  ...
#
#    Location_descr               Expertise Income_range  \
# 0  Medium Density                      it  1001-10 000
# 1  Medium Density  information technology    101-1 000
# 2  Medium Density                    data    101-1 000
# 3     Low Density  information technology    101-1 000
# 4    High Density      system development  1001-10 000
#
#                  Device_model                        Sport  \
# 0                     nokia 5            Atheletics;Soccer
# 1        laptop:thinkpad p51s                       Others
# 2                          hp                   Atheletics
# 3  laptop:hp elitebook 830 g5  Soccer;Rugby;Tennis;Cricket
# 4                    iphone 6                       Soccer
#
#                                           Technology  \
# 0  Information Technology;Agriculture;Artificial ...
# 1  Information Technology;Sensors;Transport;Appli...
# 2       Information Technology;Entertainment & Media
# 3                             Information Technology
# 4                             Information Technology
#
#                                                 News  \
# 0  hard news;feature news;Lifestyle/entertainment...
# 1  feature news;Lifestyle/entertainment;Profiles;...
# 2                  hard news;Lifestyle/entertainment
# 3  sport news;feature news;Investigative News;Tec...
# 4                                         sport news
#
#                                                Music  \
# 0                                   Gospel/religious
# 1  Gospel/religious;pop;rock;jazz;Rnb;Dance Hall;...
# 2    Gospel/religious;pop;rock;Rnb;Dance Hall;Reggae
# 3           sungura;jazz;Rnb;Dance Hall;Reggae;House
# 4                                   Gospel/religious
#
#                                              Hobbies  \
# 0                        reading;singing;watching TV
# 1                       reading;e-gaming;watching TV
# 2  Cooking;Mountain climbing;reading;fishing;e-ga...
# 3                               sporting;watching TV
# 4                                  Mountain climbing
#
#                                                 Food
# 0       legumes;Edible plants;Dairy products;Seafood
# 1  Baked goods;Breads;Dairy products;Eggs;Meat;Ce...
# 2  legumes;Edible plants;Baked goods;Breads;Dairy...
# 3                                               Meat
# 4                                               Meat
#
# [5 rows x 27 columns]

# %%
dat=dat.drop('Device_model',axis=1)

# %%
dat.Sport.head()
# Out:
# 0              Atheletics;Soccer
# 1                         Others
# 2                     Atheletics
# 3    Soccer;Rugby;Tennis;Cricket
# 4                         Soccer
# Name: Sport, dtype: object

# %%
dat.head()
# Out:
#    Gender Marital_Status                         Household     Education  \
# 0    Male        Married  immediate family;extended family      Tertiary
# 1    Male         Single                             alone  Professional
# 2  Female         Single                        sibling(s)  Professional
# 3    Male         Single                              self      Tertiary
# 4    Male        Married                  immediate family  Professional
#
#                                           Movie_type Age_range Country_Origin  \
# 0                            documentaries;religious     31-35       zimbabwe
# 1  documentaries;religious;sci-fi;comedy;romance;...     31-35       zimbabwe
# 2                       sci-fi;comedy;romance;action     21-25       zimbabwe
# 3                       sci-fi;comedy;romance;action     31-35       zimbabwe
# 4                                          religious     31-35       zimbabwe
#
#   Town_city_province      Current_staying                 Language  ...  \
# 0          goromonzi             chinhoyi            english,shona  ...
# 1             harare               harare  english, ndebele, shona  ...
# 2             harare  prospect waterfalls           english,shonja  ...
# 3           chipinge               harare           english, shona  ...
# 4             harare        budiriro cabs                  english  ...
#
#   Emotional_state  Location_descr               Expertise Income_range  \
# 0          Joyful  Medium Density                      it  1001-10 000
# 1         fearful  Medium Density  information technology    101-1 000
# 2         fearful  Medium Density                    data    101-1 000
# 3         fearful     Low Density  information technology    101-1 000
# 4          Joyful    High Density      system development  1001-10 000
#
#                          Sport  \
# 0            Atheletics;Soccer
# 1                       Others
# 2                   Atheletics
# 3  Soccer;Rugby;Tennis;Cricket
# 4                       Soccer
#
#                                           Technology  \
# 0  Information Technology;Agriculture;Artificial ...
# 1  Information Technology;Sensors;Transport;Appli...
# 2       Information Technology;Entertainment & Media
# 3                             Information Technology
# 4                             Information Technology
#
#                                                 News  \
# 0  hard news;feature news;Lifestyle/entertainment...
# 1  feature news;Lifestyle/entertainment;Profiles;...
# 2                  hard news;Lifestyle/entertainment
# 3  sport news;feature news;Investigative News;Tec...
# 4                                         sport news
#
#                                                Music  \
# 0                                   Gospel/religious
# 1  Gospel/religious;pop;rock;jazz;Rnb;Dance Hall;...
# 2    Gospel/religious;pop;rock;Rnb;Dance Hall;Reggae
# 3           sungura;jazz;Rnb;Dance Hall;Reggae;House
# 4                                   Gospel/religious
#
#                                              Hobbies  \
# 0                        reading;singing;watching TV
# 1                       reading;e-gaming;watching TV
# 2  Cooking;Mountain climbing;reading;fishing;e-ga...
# 3                               sporting;watching TV
# 4                                  Mountain climbing
#
#                                                 Food
# 0       legumes;Edible plants;Dairy products;Seafood
# 1  Baked goods;Breads;Dairy products;Eggs;Meat;Ce...
# 2  legumes;Edible plants;Baked goods;Breads;Dairy...
# 3                                               Meat
# 4                                               Meat
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Movies

# %%
movies=[]
for name, values in dat['Movie_type'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]

# %%
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Movie_type']=free

# %% [markdown]
# ### Household

# %%
movies=[]
for name, values in dat['Household'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Household']=free

# %% [markdown]
# ###  Town_city_province

# %%
movies=[]
for name, values in dat['Town_city_province'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Town_city_province']=free

# %% [markdown]
# ### Language

# %%
movies=[]
for name, values in dat['Language'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    J="".join(str(x) for x in i)
    L.append(J.split(','))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Language']=free

# %% [markdown]
# ### Mood

# %%
movies=[]
for name, values in dat['Mood'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Mood']=free

# %% [markdown]
# ### Current_situation

# %%
movies=[]
for name, values in dat['Current_situation'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Current_situation']=free

# %% [markdown]
# ### Emotional_state

# %%
movies=[]
for name, values in dat['Emotional_state'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Emotional_state']=free

# %% [markdown]
# ### Expertise

# %%
movies=[]
search=['information','it','data','computing','computer','programming','system','i.t',
        'ict4d','ict','i t','machine']
cho=['accounting']
for name, values in dat['Expertise'].iteritems():
    if any(s in values for s in search):
        movies.append("it")
    elif any(s in values for s in cho):
        movies.append("accounting") 
    else:
        movies.append(values)

dat['Expertise']=movies

# %% [markdown]
# ### Sport

# %%
movies=[]
for name, values in dat['Sport'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Sport']=free

# %% [markdown]
# ## Techonology

# %%
movies=[]
for name, values in dat['Technology'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Technology']=free

# %% [markdown]
# ### News

# %%
movies=[]
for name, values in dat['News'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['News']=free

# %% [markdown]
# ## Music

# %%
movies=[]
for name, values in dat['Music'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Music']=free

# %% [markdown]
# ## Hobbies

# %%
movies=[]
for name, values in dat['Hobbies'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Hobbies']=free

# %% [markdown]
# ## Food

# %%
movies=[]
for name, values in dat['Food'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Food']=free

# %%
dat
# Out:
#      Gender Marital_Status          Household     Education  \
# 0      Male        Married   immediate family      Tertiary
# 1      Male         Single              alone  Professional
# 2    Female         Single         sibling(s)  Professional
# 3      Male         Single               self      Tertiary
# 4      Male        Married   immediate family  Professional
# 5    Female         Single   immediate family      Tertiary
# 6      Male         Single    extended family      Tertiary
# 7      Male        Married   immediate family      Tertiary
# 8      Male        Married   immediate family      Tertiary
# 9      Male         Single              alone      Tertiary
# 10   Female        Married  husband and child      Tertiary
# 11     Male        Married   immediate family      Tertiary
# 12     Male         Single          friend(s)      Tertiary
# 13     Male        Married   immediate family  Professional
# 14     Male        Married   immediate family  Professional
# 15   Female         Single   immediate family      Tertiary
# 16     Male        Married   immediate family      Tertiary
# 17     Male        Married   immediate family      Tertiary
# 18   Female         Single   immediate family  Professional
# 19     Male         Single    extended family      Tertiary
# 20     Male        Married   immediate family      Tertiary
# 21     Male         Single   immediate family      Tertiary
# 22   Female         Single   immediate family      Tertiary
# 23     Male        Married   immediate family      Tertiary
# 24     Male         Single         sibling(s)      Tertiary
# 25     Male         Single   immediate family  Professional
# 26     Male        Married   immediate family      Tertiary
# 27   Female        Married   immediate family  Professional
# 28     Male        Married   immediate family  Professional
# 29     Male         Single              alone      Tertiary
# ..      ...            ...                ...           ...
# 117    Male         Single          friend(s)      Tertiary
# 118  Female          Other   immediate family      Tertiary
# 119  Female         Single   immediate family      Tertiary
# 120    Male        Married   immediate family      Tertiary
# 121  Female         Single   immediate family  Professional
# 122  Female        Married   immediate family      Tertiary
# 123    Male         Single              alone      Tertiary
# 124  Female         Single             mother      Tertiary
# 125    Male        Married   immediate family      Tertiary
# 126    Male        Married   immediate family  Professional
# 127    Male        Married   immediate family  Professional
# 128    Male         Single   immediate family      Tertiary
# 129    Male        Married   immediate family      Tertiary
# 130  Female         Single   immediate family      Tertiary
# 131    Male         Single              alone      Tertiary
# 132    Male        Married   immediate family      Tertiary
# 133  Female        Married   immediate family  Professional
# 134    Male         Single   immediate family      Tertiary
# 135    Male        Married   immediate family      Tertiary
# 136    Male        Married   immediate family      Tertiary
# 137  Female        Married   immediate family  Professional
# 138    Male         Single   immediate family  Professional
# 139  Female          Other   immediate family  Professional
# 140    Male        Married   immediate family      Tertiary
# 141    Male        Married   immediate family      Tertiary
# 142    Male         Single   immediate family      Tertiary
# 143    Male        Married    extended family      Tertiary
# 144    Male        Married   immediate family  Professional
# 145  Female         Single   immediate family  Professional
# 146    Male        Married   immediate family      Tertiary
#
#             Movie_type Age_range Country_Origin  \
# 0        documentaries     31-35       zimbabwe
# 1        documentaries     31-35       zimbabwe
# 2               sci-fi     21-25       zimbabwe
# 3               sci-fi     31-35       zimbabwe
# 4            religious     31-35       zimbabwe
# 5    i not into movies     21-25       zimbabwe
# 6               sci-fi     21-25       zimbabwe
# 7               action     41-45       zimbabwe
# 8        documentaries     36-40       zimbabwe
# 9                 epic     21-25       zimbabwe
# 10              comedy     26-30       zimbabwe
# 11              action     26-30       zimbabwe
# 12       documentaries     26-30       zimbabwe
# 13       documentaries     26-30       zimbabwe
# 14       documentaries     31-35       zimbabwe
# 15              sci-fi     36-40       zimbabwe
# 16       documentaries     31-35       zimbabwe
# 17           religious     21-25       zimbabwe
# 18              sci-fi     26-30       zimbabwe
# 19              sci-fi     21-25      zimbabwe
# 20       documentaries     31-35       zimbabwe
# 21              action     26-30       zimbabwe
# 22       documentaries     46-50       zimbabwe
# 23       documentaries     26-30       zimbabwe
# 24       documentaries     26-30      zimbabwe
# 25              sci-fi     21-25       zimbabwe
# 26              action     36-40       zimbabwe
# 27              comedy     41-45       zimbabwe
# 28       documentaries     41-45       zimbabwe
# 29       documentaries     26-30       zimbabwe
# ..                 ...       ...            ...
# 117             sci-fi     31-35       zimbabwe
# 118          religious     46-50       zimbabwe
# 119             sci-fi     26-30      zimbabwe
# 120          religious     31-35       zimbabwe
# 121      documentaries     26-30       zimbabwe
# 122      documentaries     31-35       zimbabwe
# 123      documentaries     26-30       zimbabwe
# 124            romance     26-30       zimbabwe
# 125             sci-fi     36-40       zimbabwe
# 126          religious     36-40       zimbabwe
# 127      documentaries     36-40       zimbabwe
# 128          religious     26-30       zimbabwe
# 129      documentaries     26-30       zimbabwe
# 130          religious     31-35       zimbabwe
# 131          religious     31-35       zimambwe
# 132      documentaries     46-50       zimbabwe
# 133      documentaries     26-30       zimbabwe
# 134      documentaries     21-25       zimbabwe
# 135             action     36-40       zimbabwe
# 136             action     41-45       zimbabwe
# 137             comedy     36-40            zim
# 138      documentaries     26-30       zimbabwe
# 139            romance     36-40       zimbabwe
# 140      documentaries     36-40       zimbabwe
# 141      documentaries     26-30       zimbabwe
# 142      documentaries     26-30       zimbabwe
# 143      documentaries     36-40       zimbabwe
# 144      documentaries     31-35       zimbabwe
# 145      documentaries     26-30       zimbabwe
# 146      documentaries     31-35       zimbabwe
#
#                      Town_city_province                Current_staying  \
# 0                             goromonzi                       chinhoyi
# 1                                harare                         harare
# 2                                harare            prospect waterfalls
# 3                              chipinge                         harare
# 4                                harare                  budiriro cabs
# 5                                harare                    chitungwiza
# 6                                kadoma                         harare
# 7                                 karoi                    chitungwiza
# 8                                harare                         harare
# 9                              masvingo                         harare
# 10                           manicaland                         harare
# 11                               harare                       budiriro
# 12                            bulawayo                          harare
# 13                               harare                 ruwa, zimbabwe
# 14                     mashonaland east                         harare
# 15                               norton                         norton
# 16                     mashonaland west                        bindura
# 17   chinhoyi/mashonaland west province              brundish chinhoyi
# 18                               harare                       chinhoyi
# 19                               harare                         harare
# 20                             chinhoyi                       chinhoyi
# 21                               kwekwe                         harare
# 22                               chivhu                       chinhoyi
# 23                               mutare                         harare
# 24                               harare                      zimbabwe
# 25                               harare                     domboshava
# 26                               harare            chinhoyi university
# 27                               harare                         harare
# 28                               mutare                         harare
# 29                   mashonaland   east                         harare
# ..                                  ...                            ...
# 117                            bulawayo                         harare
# 118                              harare                         harare
# 119                   mashonaland east                          harare
# 120                              harare                        eastlea
# 121                            masvingo                         norton
# 122                              harare                       westgate
# 123                             bindura                         harare
# 124                             chegutu                         mother
# 125                              harare                     waterfalls
# 126                              harare                         harare
# 127                                gutu                          ngezi
# 128                            chinhoyi                         harare
# 129                          manicaland                         harare
# 130                              harare                    chitungwiza
# 131                           mash east                         harare
# 132                            masvingo                         harare
# 133                              rusape                   dzivarasekwa
# 134                              harare                         harare
# 135                           mash east  goromonzi,mash east ,zimbabwe
# 136                            midlands                         harare
# 137                             chegutu                         harare
# 138                              kadoma                         harare
# 139                  chitungwiza,harare             chitungwiza,harare
# 140                              harare                      australia
# 141                               gweru                       watsomba
# 142                              harare                    glen view 7
# 143                    mashonaland east                       chinhoyi
# 144                              mutoko                         harare
# 145                            masvingo                         norton
# 146                              mutare                         harare
#
#                Language  ... Emotional_state  Location_descr        Expertise  \
# 0               english  ...          Joyful  Medium Density               it
# 1               english  ...         fearful  Medium Density               it
# 2               english  ...         fearful  Medium Density               it
# 3               english  ...         fearful     Low Density               it
# 4               english  ...          Joyful    High Density               it
# 5               english  ...          Joyful    High Density               it
# 6     english and shona  ...          Joyful  Medium Density               it
# 7               english  ...          Joyful    High Density               it
# 8                 shona  ...         fearful    High Density         commerce
# 9     shona and english  ...          Joyful     Low Density               it
# 10    english and shona  ...          Joyful    High Density         busineds
# 11                shona  ...          Joyful    High Density               it
# 12              ndebele  ...          Joyful  Medium Density               it
# 13                shona  ...          Joyful    High Density               it
# 14                shona  ...          Joyful  Medium Density               it
# 15              english  ...         fearful     Low Density               it
# 16                shona  ...          Joyful  Medium Density      procurement
# 17                shona  ...          Joyful  Medium Density      engineering
# 18              english  ...          Joyful    High Density               it
# 19             english   ...          Joyful  Medium Density     engineering
# 20                shona  ...       sorrowful     Low Density      engineering
# 21   english and shona   ...          Joyful  Medium Density       marketing
# 22              english  ...         fearful     Low Density               it
# 23              english  ...          Joyful    High Density               it
# 24              english  ...          Joyful  Medium Density               it
# 25                shona  ...          Joyful           Rural               it
# 26                shona  ...          Joyful     Low Density       networking
# 27    shona and english  ...         fearful     Low Density               it
# 28              english  ...          Joyful     Low Density               it
# 29                shona  ...          Joyful     Low Density               it
# ..                  ...  ...             ...             ...              ...
# 117             ndebele  ...          Joyful  Medium Density               it
# 118   shona and english  ...          Joyful  Medium Density         commerce
# 119  english and shona   ...          Joyful  Medium Density      statistics
# 120   english and shona  ...          Joyful     Low Density          science
# 121            english   ...         fearful  Medium Density      engineering
# 122             english  ...          Joyful     Low Density          finance
# 123               shona  ...          Joyful    High Density      engineering
# 124               shona  ...          Joyful  Medium Density               it
# 125               shona  ...          Joyful  Medium Density               it
# 126               shona  ...          Joyful  Medium Density        marketing
# 127             english  ...          Joyful           Rural          geology
# 128              shona   ...          Joyful  Medium Density               it
# 129       shona english  ...          Joyful  Medium Density               it
# 130             english  ...          Joyful    High Density               it
# 131             english  ...          Joyful  Medium Density               it
# 132               shona  ...          Joyful  Medium Density      engineering
# 133               shona  ...          Joyful  Medium Density  bids management
# 134             english  ...          Joyful  Medium Density       statistics
# 135            english   ...       sorrowful           Rural        education
# 136             english  ...          Joyful    High Density       accounting
# 137     shona & english  ...         fearful  Medium Density   business admin
# 138   english and shona  ...          Joyful     Low Density       accounting
# 139             english  ...          Joyful  Medium Density       accounting
# 140             english  ...          Joyful     Low Density               it
# 141               shona  ...          Joyful           Rural  social sciences
# 142   shona and english  ...          Joyful    High Density            risk
# 143             english  ...         fearful  Medium Density          tourism
# 144               shona  ...          Joyful  Medium Density      engineering
# 145            english   ...         fearful  Medium Density      engineering
# 146   shona and english  ...          Joyful    High Density               it
#
#     Income_range       Sport              Technology                     News  \
# 0    1001-10 000  Atheletics  Information Technology                hard news
# 1      101-1 000      Others  Information Technology             feature news
# 2      101-1 000  Atheletics  Information Technology                hard news
# 3      101-1 000      Soccer  Information Technology               sport news
# 4    1001-10 000      Soccer  Information Technology               sport news
# 5      101-1 000  Atheletics  Information Technology  Lifestyle/entertainment
# 6      101-1 000      Soccer  Information Technology               sport news
# 7    1001-10 000  Atheletics  Information Technology                hard news
# 8      101-1 000  Atheletics  Information Technology                hard news
# 9      101-1 000      Soccer  Information Technology               sport news
# 10     101-1 000      Others  Information Technology                hard news
# 11   1001-10 000      Soccer  Information Technology               sport news
# 12   1001-10 000      Soccer  Information Technology               sport news
# 13         1-100      Soccer  Information Technology                hard news
# 14   1001-10 000  Atheletics  Information Technology               sport news
# 15         1-100    Swimming  Information Technology  Lifestyle/entertainment
# 16   1001-10 000  Atheletics  Information Technology               sport news
# 17     101-1 000      Soccer  Information Technology               sport news
# 18     101-1 000  Atheletics  Information Technology               sport news
# 19     101-1 000  Atheletics  Information Technology  Lifestyle/entertainment
# 20     101-1 000  Atheletics  Information Technology                hard news
# 21     101-1 000  Atheletics  Information Technology               sport news
# 22   1001-10 000      Soccer  Information Technology               sport news
# 23   1001-10 000      Soccer  Information Technology               sport news
# 24   1001-10 000       Rugby  Information Technology                hard news
# 25     101-1 000      Others  Information Technology                Tech News
# 26   1001-10 000      Soccer  Information Technology               sport news
# 27   1001-10 000    Swimming  Information Technology             feature news
# 28   1001-10 000  Atheletics  Information Technology                hard news
# 29     101-1 000      Soccer  Information Technology               sport news
# ..           ...         ...                     ...                      ...
# 117  1001-10 000      Others  Information Technology                hard news
# 118  1001-10 000      Tennis   Entertainment & Media             feature news
# 119    101-1 000    Swimming                 Science  Lifestyle/entertainment
# 120  1001-10 000       Rugby  Information Technology                hard news
# 121        1-100      Others  Information Technology  Lifestyle/entertainment
# 122  1001-10 000      Soccer  Information Technology               sport news
# 123    101-1 000      Tennis  Information Technology                Tech News
# 124    101-1 000     Cricket  Information Technology  Lifestyle/entertainment
# 125  1001-10 000  Atheletics  Information Technology               sport news
# 126    101-1 000      Tennis  Information Technology               sport news
# 127  1001-10 000       Rugby  Information Technology                hard news
# 128    101-1 000  Atheletics  Information Technology                hard news
# 129  1001-10 000  Atheletics  Information Technology                hard news
# 130        1-100  Atheletics  Information Technology                hard news
# 131    101-1 000      Soccer  Information Technology               sport news
# 132  1001-10 000  Atheletics  Information Technology                hard news
# 133    101-1 000      Others   Entertainment & Media  Lifestyle/entertainment
# 134    101-1 000       Rugby  Information Technology                hard news
# 135        1-100      Soccer  Information Technology               sport news
# 136  1001-10 000      Others  Information Technology                hard news
# 137    101-1 000  Atheletics  Information Technology                hard news
# 138    101-1 000  Atheletics  Information Technology                hard news
# 139    101-1 000  Atheletics  Information Technology                Tech News
# 140  1001-10 000      Tennis  Information Technology                hard news
# 141  1001-10 000      Soccer             Agriculture                hard news
# 142  1001-10 000     Cricket                  Energy            Business News
# 143  1001-10 000      Others             Agriculture                hard news
# 144  1001-10 000  Atheletics  Information Technology               sport news
# 145        1-100      Others  Information Technology  Lifestyle/entertainment
# 146  1001-10 000      Soccer  Information Technology               sport news
#
#                 Music            Hobbies                   Food
# 0    Gospel/religious            reading                legumes
# 1    Gospel/religious            reading            Baked goods
# 2    Gospel/religious            Cooking                legumes
# 3             sungura           sporting                   Meat
# 4    Gospel/religious  Mountain climbing                   Meat
# 5    Gospel/religious            Cooking         Dairy products
# 6    Gospel/religious           e-gaming                   Meat
# 7             sungura            reading          Edible plants
# 8    Gospel/religious            reading  Edible nuts and seeds
# 9    Gospel/religious  Mountain climbing          Edible plants
# 10   Gospel/religious            Cooking            Baked goods
# 11   Gospel/religious            reading         Dairy products
# 12                pop            reading                   Eggs
# 13   Gospel/religious            reading                legumes
# 14   Gospel/religious            reading          Edible plants
# 15   Gospel/religious            Cooking                legumes
# 16            sungura            reading                Cereals
# 17   Gospel/religious         Dance Hall         Dairy products
# 18   Gospel/religious            Cooking  Edible nuts and seeds
# 19   Gospel/religious            reading                legumes
# 20            sungura            Cooking                legumes
# 21   Gospel/religious  Mountain climbing                   Meat
# 22   Gospel/religious            reading  Edible nuts and seeds
# 23   Gospel/religious           sporting  Edible nuts and seeds
# 24                pop            reading            Baked goods
# 25         Dance Hall            reading                legumes
# 26               jazz            fishing            Baked goods
# 27   Gospel/religious            Cooking          Edible plants
# 28   Gospel/religious  Mountain climbing                   Meat
# 29   Gospel/religious  Mountain climbing                legumes
# ..                ...                ...                    ...
# 117  Gospel/religious        watching TV                   Eggs
# 118  Gospel/religious            reading                 Breads
# 119  Gospel/religious            Cooking                legumes
# 120               pop            Cooking                legumes
# 121  Gospel/religious            Cooking         Dairy products
# 122  Gospel/religious            Cooking          Edible plants
# 123  Gospel/religious            Cooking                legumes
# 124  Gospel/religious        watching TV                   Meat
# 125  Gospel/religious           sporting                 Breads
# 126  Gospel/religious           sporting         Dairy products
# 127  Gospel/religious            reading                legumes
# 128  Gospel/religious            Cooking                legumes
# 129               pop            reading  Edible nuts and seeds
# 130  Gospel/religious            Cooking                   Eggs
# 131  Gospel/religious           sporting                legumes
# 132  Gospel/religious  Mountain climbing                legumes
# 133  Gospel/religious            Cooking                legumes
# 134              rock            reading                legumes
# 135           sungura           sporting                   Meat
# 136            Reggae            reading                   Meat
# 137  Gospel/religious  Mountain climbing  Edible nuts and seeds
# 138  Gospel/religious  Mountain climbing                legumes
# 139  Gospel/religious            reading                legumes
# 140  Gospel/religious            Cooking  Edible nuts and seeds
# 141           sungura  Mountain climbing                 Breads
# 142  Gospel/religious            reading                   Meat
# 143  Gospel/religious            reading            Baked goods
# 144           sungura           sporting                   Meat
# 145  Gospel/religious            Cooking         Dairy products
# 146  Gospel/religious            Cooking                legumes
#
# [147 rows x 26 columns]

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori  
records = []  
for i in range(0, 100):  
    records.append([str(dat.values[i,j]) for j in range(0, 26)])
association_rules = apriori(records, min_support=0.1, min_confidence=0.6, min_lift=3.50, min_length=10)  
association_results = list(association_rules)
print(len(association_results))

# %%
print(association_results[0])

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")

# %%
type(association_results)

# %%
for i in association_results[:4]:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a7c9be21d493> in <module>
# ----> 1 for i in association_results[:4]:
#       2     print(i)
#
# NameError: name 'association_results' is not defined

# %%
type(association_results[0])

# %%
import pickle
MB=association_results
with open('Rules.txt', 'wb') as fp:
    pickle.dump(MB, fp)

# %%
import pickle
with open ('Rules.txt', 'rb') as fp:
    itemlist = pickle.load(fp)

# %%
MB = itemlist
listRules = [list(MB[i][0]) for i in range(0,len(MB))]
len(listRules)
# Out:
# 160

# %%
liscon=[]
for i in range(0,len(MB)):
    liscon.append(MB[i][1])
new_df=pd.DataFrame({'Rules':listRules,'Support_Ratio':liscon})
new_df.head(11)
# Out:
#                                                 Rules  Support_Ratio
# 0         [Cooking, Gospel/religious, Joyful, Female]           0.14
# 1    [Low Density, Cooking, Gospel/religious, Female]           0.13
# 2        [Cooking, Gospel/religious, Married, Female]           0.13
# 3       [Cooking, Gospel/religious, Tertiary, Female]           0.13
# 4   [Gospel/religious, Cooking, Female, 101-1 000,...           0.12
# 5   [harare, Gospel/religious, Cooking, Female, 10...           0.10
# 6   [Gospel/religious, Christianity, Cooking, Fema...           0.14
# 7   [Gospel/religious, Christianity, Low Density, ...           0.13
# 8   [Gospel/religious, Christianity, Married, Cook...           0.13
# 9   [Gospel/religious, Christianity, Cooking, Fema...           0.13
# 10  [Information Technology, Gospel/religious, Low...           0.10

# %%
s=set()
import numpy as np
for i in new_df.ix[np.arange(len(new_df)),'Rules']:
    for j in i:
        s.add(j)
s
# Out:
# /home/kavhu/ml/env/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# {'101-1 000',
#  'Christianity',
#  'Cooking',
#  'Female',
#  'Gospel/religious',
#  'Information Technology',
#  'Joyful',
#  'Low Density',
#  'Married',
#  'No',
#  'Tertiary',
#  'Yes',
#  'good',
#  'harare',
#  'immediate family',
#  'zimbabwe'}

# %%
'Female' in new_df.ix[0,'Rules']
female_list=[]
for i,rows in new_df.iterrows():
#     print(i,rows['Rules'])
    if('Female' in rows['Rules']):
        female_list.append(rows['Support_Ratio'])
#         count+=1
# data=pd.DataFrame({'Female':['female']*len(female_list),'support':female_list})
# data.head()
data={}
data['female']=female_list
data['low_density']=[rows['Support_Ratio'] for i,rows in new_df.iterrows() if('Low Density' in rows['Rules'])]
# Out:
# /home/kavhu/ml/env/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
D={}
for j in s:
    D[j]=[rows['Support_Ratio'] for i,rows in new_df.iterrows() if(j in rows['Rules'])]
del D['No']

# %%
import plotly.plotly as py
import plotly.tools as tls

from matplotlib import pylab
import matplotlib.pyplot as plt
names = list(D.keys())
values = list(D.values())
width = 1 
for i in range(len(D)):
    
    pylab.bar(i,values[i],width,tick_label=names[i])
#     plt.bar(1,values[1],tick_label=names[1])
#     plt.bar(2,values[2],tick_label=names[2])
    plt.xticks(range(0,i),names,fontsize=12, rotation=30)
#plt.figure(figsize=(100,100))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylabel('Support Ratio',fontsize=14)
plt.xlabel('User Profile',fontsize=14)
plt.title('User Profile Dominance against Support Ratio',fontsize=14)
plt.savefig('association.png')
plt.show()

# %%
d1={'good':'Mood','Cooking':'Hobbies','Married':'Marital_Status',
   '101-1 000':'Income','Yes':'Studying/Not_Studying','Low Density':'Home_Area',
    'Tertiary':'Education_Level','harare':'City','Female':'Gender','immediate family':'Family',
   'Christianity':'Religion','zimbabwe':'Nationality','Information Technology':'Expertise',
   'Gospel/religious':'Music','Joyful':'Emotional_State'}
k=dict((d1[key], value) for (key, value) in D.items())
D=k
# list(D.keys())

# %%
import plotly.plotly as py
import plotly.tools as tls

from matplotlib import pylab
names = list(D.keys())
values = list(D.values())
width = 1 
for i in range(len(D)):
    
    pylab.bar(i,values[i],width,tick_label=names[i])
#     plt.bar(1,values[1],tick_label=names[1])
#     plt.bar(2,values[2],tick_label=names[2])
    plt.xticks(range(0,i),names,fontsize=12,rotation=30)
#plt.figure(figsize=(100,100))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylabel('Support Ratio',fontsize=14)
plt.xlabel('User Contexts',fontsize=14)
plt.title('User Profile Dominance against Support Ratio',fontsize=14)
plt.savefig('association.png')
plt.show()

# %%
L=[]
# for i in range(0,len(MB)):
#     L.append(MB[2][2][0][2])
for i in range(0,len(MB)):
    L.append(MB[i][2][0][2])
d=pd.DataFrame({'Rules':listRules,'Confidence':L})
d.head(11)
# Out:
#                                                 Rules  Confidence
# 0         [Cooking, Gospel/religious, Joyful, Female]    0.875000
# 1    [Low Density, Cooking, Gospel/religious, Female]    0.928571
# 2        [Cooking, Gospel/religious, Married, Female]    0.928571
# 3       [Cooking, Gospel/religious, Tertiary, Female]    0.928571
# 4   [Gospel/religious, Cooking, Female, 101-1 000,...    0.923077
# 5   [harare, Gospel/religious, Cooking, Female, 10...    0.909091
# 6   [Gospel/religious, Christianity, Cooking, Fema...    0.875000
# 7   [Gospel/religious, Christianity, Low Density, ...    0.928571
# 8   [Gospel/religious, Christianity, Married, Cook...    0.928571
# 9   [Gospel/religious, Christianity, Cooking, Fema...    0.928571
# 10  [Information Technology, Gospel/religious, Low...    0.909091

# %%
s=set()
import numpy as np
for i in d.ix[np.arange(len(d)),'Rules']:
    for j in i:
        s.add(j)
# Out:
# /home/kavhu/ml/env/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
D={}
for j in s:
    D[j]=[rows['Confidence'] for i,rows in d.iterrows() if(j in rows['Rules'])]
del D['No']

# %%
d1={'good':'Mood','Cooking':'Hobbies','Married':'Marital_Status',
   '101-1 000':'Income','Yes':'Studying/Not_Studying','Low Density':'Home_Area',
    'Tertiary':'Education_Level','harare':'City','Female':'Gender','immediate family':'Family',
   'Christianity':'Religion','zimbabwe':'Nationality','Information Technology':'Expertise',
   'Gospel/religious':'Music','Joyful':'Emotional_State'}
k=dict((d1[key], value) for (key, value) in D.items())
D=k

# %%
import plotly.plotly as py
import plotly.tools as tls

from matplotlib import pylab
names = list(D.keys())
values = list(D.values())
width = 1 
for i in range(len(D)):
    
    pylab.bar(i,values[i],width,tick_label=names[i])
#     plt.bar(1,values[1],tick_label=names[1])
#     plt.bar(2,values[2],tick_label=names[2])
    plt.xticks(range(0,i),names,fontsize=12,rotation=30)
#plt.figure(figsize=(100,100))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylabel('Confidence Values(Factors)',fontsize=14)
plt.xlabel('User Contexts',fontsize=14)
plt.title('User Profile Dominance against Confidence Value',fontsize=14)
plt.savefig('Confidence.png')
plt.show()
