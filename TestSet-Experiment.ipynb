# %%
import pandas as pd
# df=pd.read_csv("Assessment.csv")
# df.head()
# !pip install -U -q PyDrive 
  
# from pydrive.auth import GoogleAuth 
# from pydrive.drive import GoogleDrive 
# from google.colab import auth 
# from oauth2client.client import GoogleCredentials 
  
  
# # Authenticate and create the PyDrive client. 
# auth.authenticate_user() 
# gauth = GoogleAuth() 
# gauth.credentials = GoogleCredentials.get_application_default() 
# drive = GoogleDrive(gauth)
# link = 'https://drive.google.com/file/d/1iLqKs8n24XHoiZ4bAwCPGeDi9yox_TSW/view?usp=sharing' 
  
# import pandas as pd 
  
# # to get the id part of the file 
# id = link.split("/")[-2] 
  
# downloaded = drive.CreateFile({'id':id})  
# downloaded.GetContentFile('Assessment.csv')

# %%
df = pd.read_csv('Assessment.csv', names=['Time','Gender','Marital_Status','Household','Education','Movie_type','Age_range','Country_Origin',
                                           'Town_city_province','Current_staying','Language','Religion','Mood','Current_situation','Have_Stress',
                                           'Studying','Event_in_two_weeks','Emotional_state','Location_descr','Expertise','Income_range',
                                           'Device_model','Sport','Technology','News','Music','Hobbies','Food'])

# %%
df=df.iloc[1:,:]
df.shape
# Out:
# (306, 28)

# %%
df=df.iloc[:,1:]

# %%
df['Country_Origin']=df['Country_Origin'].str.lower()
df['Town_city_province']=df['Town_city_province'].str.lower()
df['Current_staying']=df['Current_staying'].str.lower()
df['Language']=df['Language'].str.lower()
df['Expertise']=df['Expertise'].str.lower()
df['Device_model']=df['Device_model'].str.lower()
df['Household']=df['Household'].str.lower()
df['Movie_type']=df['Movie_type'].str.lower()
df['Expertise']=df['Expertise'].str.lower()
dat=df

# %%
dat.head()
# Out:
#    Gender Marital_Status                         Household     Education  \
# 1    Male        Married  immediate family;extended family      Tertiary
# 2    Male         Single                             alone  Professional
# 3  Female         Single                        sibling(s)  Professional
# 4    Male         Single                              self      Tertiary
# 5    Male        Married                  immediate family  Professional
#
#                                           Movie_type Age_range Country_Origin  \
# 1                            documentaries;religious     31-35       zimbabwe
# 2  documentaries;religious;sci-fi;comedy;romance;...     31-35       zimbabwe
# 3                       sci-fi;comedy;romance;action     21-25       zimbabwe
# 4                       sci-fi;comedy;romance;action     31-35       zimbabwe
# 5                                          religious     31-35       zimbabwe
#
# ...

# %%
dat=dat.drop('Device_model',axis=1)

# %%
dat.Sport.head()
# Out:
# 1              Atheletics;Soccer
# 2                         Others
# 3                     Atheletics
# 4    Soccer;Rugby;Tennis;Cricket
# 5                         Soccer
# Name: Sport, dtype: object

# %%
dat.head()
# Out:
#    Gender Marital_Status                         Household     Education  \
# 1    Male        Married  immediate family;extended family      Tertiary
# 2    Male         Single                             alone  Professional
# 3  Female         Single                        sibling(s)  Professional
# 4    Male         Single                              self      Tertiary
# 5    Male        Married                  immediate family  Professional
#
#                                           Movie_type Age_range Country_Origin  \
# 1                            documentaries;religious     31-35       zimbabwe
# 2  documentaries;religious;sci-fi;comedy;romance;...     31-35       zimbabwe
# 3                       sci-fi;comedy;romance;action     21-25       zimbabwe
# 4                       sci-fi;comedy;romance;action     31-35       zimbabwe
# 5                                          religious     31-35       zimbabwe
#
# ...

# %%
dat.columns
# Out:
# Index(['Gender', 'Marital_Status', 'Household', 'Education', 'Movie_type',
#        'Age_range', 'Country_Origin', 'Town_city_province', 'Current_staying',
#        'Language', 'Religion', 'Mood', 'Current_situation', 'Have_Stress',
#        'Studying', 'Event_in_two_weeks', 'Emotional_state', 'Location_descr',
#        'Expertise', 'Income_range', 'Sport', 'Technology', 'News', 'Music',
#        'Hobbies', 'Food'],
#       dtype='object')

# %% [markdown]
# ### Movies

# %%
movies=[]
for name, values in dat['Movie_type'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]

# %%
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Movie_type']=free

# %% [markdown]
# ### Household

# %%
movies=[]
for name, values in dat['Household'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Household']=free

# %% [markdown]
# ###  Town_city_province

# %%
movies=[]
for name, values in dat['Town_city_province'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    # if(type(i)==str):
    L.append(str(i).split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Town_city_province']=free

# %% [markdown]
# ### Language

# %%
movies=[]
for name, values in dat['Language'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    J="".join(str(x) for x in i)
    L.append(J.split(','))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Language']=free

# %% [markdown]
# ### Mood

# %%
movies=[]
for name, values in dat['Mood'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Mood']=free

# %% [markdown]
# ### Current_situation

# %%
movies=[]
for name, values in dat['Current_situation'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Current_situation']=free

# %% [markdown]
# ### Emotional_state

# %%
movies=[]
for name, values in dat['Emotional_state'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Emotional_state']=free

# %% [markdown]
# ### Expertise

# %%
movies=[]
search=['information','it','data','computing','computer','programming','system','i.t',
        'ict4d','ict','i t','machine']
cho=['accounting']
for name, values in dat['Expertise'].iteritems():
    if any(s in values for s in search):
        movies.append("it")
    elif any(s in values for s in cho):
        movies.append("accounting") 
    else:
        movies.append(values)

dat['Expertise']=movies

# %% [markdown]
# ### Sport

# %%
movies=[]
for name, values in dat['Sport'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Sport']=free

# %% [markdown]
# ## Techonology

# %%
movies=[]
for name, values in dat['Technology'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Technology']=free

# %% [markdown]
# ### News

# %%
movies=[]
for name, values in dat['News'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['News']=free

# %% [markdown]
# ## Music

# %%
movies=[]
for name, values in dat['Music'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Music']=free

# %% [markdown]
# ## Hobbies

# %%
movies=[]
for name, values in dat['Hobbies'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Hobbies']=free

# %% [markdown]
# ## Food

# %%
movies=[]
for name, values in dat['Food'].iteritems():
    movies.append(values)
L=[]
for i in movies:
    L.append(i.split(';'))
free=[]
free.append(L[0][0])
i=1
while i<len(L):
    if(len(L[i])==1):
        for k in L[i]:
            free.append(k)
    else:
        for j in L[i]:
            if(j in L[i-1]):
                free.append(j)
                break
            else:
                free.append(j)
                break
    i+=1
dat['Food']=free

# %%
dat
# Out:
#      Gender Marital_Status          Household     Education  \
# 1      Male        Married   immediate family      Tertiary
# 2      Male         Single              alone  Professional
# 3    Female         Single         sibling(s)  Professional
# 4      Male         Single               self      Tertiary
# 5      Male        Married   immediate family  Professional
# 6    Female         Single   immediate family      Tertiary
# 7      Male         Single    extended family      Tertiary
# 8      Male        Married   immediate family      Tertiary
# 9      Male        Married   immediate family      Tertiary
# 10     Male         Single              alone      Tertiary
# 11   Female        Married  husband and child      Tertiary
# 12     Male        Married   immediate family      Tertiary
# 13     Male         Single          friend(s)      Tertiary
# 14     Male        Married   immediate family  Professional
# 15     Male        Married   immediate family  Professional
# ...

# %%
# !pip install apyori

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori  
records = []  
for i in range(0, 100):  
    records.append([str(dat.values[i,j]) for j in range(0, 26)])
association_rules = apriori(records, min_support=0.10, min_confidence=0.6, min_lift=3.50, min_length=10)  
association_results = list(association_rules)
print(len(association_results))
# Out:
# 160

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Cooking', 'Female', 'Gospel/religious', 'Joyful'}), support=0.14, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cooking', 'Gospel/religious', 'Joyful'}), items_add=frozenset({'Female'}), confidence=0.8750000000000001, lift=3.5000000000000004)])

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Cooking -> Female
# Support: 0.14
# Confidence: 0.8750000000000001
# Lift: 3.5000000000000004
# ...
# Rule: Cooking -> Female
# Support: 0.13
# Confidence: 0.9285714285714285
# Lift: 3.714285714285714
# ...
# Rule: Cooking -> Married
# Support: 0.13
# Confidence: 0.9285714285714285
# Lift: 3.714285714285714
# ...
# Rule: Cooking -> Tertiary
# Support: 0.13
# Confidence: 0.9285714285714285
# Lift: 3.714285714285714
# ...
# Rule: 101-1 000 -> Gospel/religious
# Support: 0.12
# Confidence: 0.923076923076923
# Lift: 3.692307692307692
# ...
# Rule: 101-1 000 -> harare
# Support: 0.1
# Confidence: 0.9090909090909092
# Lift: 3.6363636363636367
# ...
# Rule: Gospel/religious -> Christianity
# Support: 0.14
# Confidence: 0.8750000000000001
# Lift: 3.5000000000000004
# ...
# Rule: Gospel/religious -> Low Density
# Support: 0.13
# Confidence: 0.9285714285714285
# Lift: 3.714285714285714
# ...
# Rule: Gospel/religious -> Christianity
# Support: 0.13
# Confidence: 0.9285714285714285
# Lift: 3.714285714285714
# ...

# %%
type(association_results)
# Out:
# list

# %%
for i in association_results[:4]:
    print(i)
# Out:
# RelationRecord(items=frozenset({'Cooking', 'Female', 'Gospel/religious', 'Joyful'}), support=0.14, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cooking', 'Gospel/religious', 'Joyful'}), items_add=frozenset({'Female'}), confidence=0.8750000000000001, lift=3.5000000000000004)])
# RelationRecord(items=frozenset({'Cooking', 'Female', 'Low Density', 'Gospel/religious'}), support=0.13, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cooking', 'Low Density', 'Gospel/religious'}), items_add=frozenset({'Female'}), confidence=0.9285714285714285, lift=3.714285714285714)])
# RelationRecord(items=frozenset({'Cooking', 'Married', 'Female', 'Gospel/religious'}), support=0.13, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cooking', 'Married', 'Gospel/religious'}), items_add=frozenset({'Female'}), confidence=0.9285714285714285, lift=3.714285714285714)])
# ...

# %%
type(association_results[0])
# Out:
# apyori.RelationRecord

# %%
import pickle
MB=association_results
with open('Rules.txt', 'wb') as fp:
    pickle.dump(MB, fp)

# %%
import pickle
with open('Rules.txt', 'rb') as fp:
    itemlist = pickle.load(fp)

# %%
MB = itemlist
listRules = [list(MB[i][0]) for i in range(0,len(MB))]
len(listRules)
# Out:
# 160

# %%
import pandas as pd

liscon=[]
for i in range(0,len(MB)):
    liscon.append(MB[i][1])
new_df=pd.DataFrame({'Rules':listRules,'Support_Ratio':liscon})
new_df.head(11)
# Out:
#                                                 Rules  Support_Ratio
# 0         [Gospel/religious, Joyful, Cooking, Female]           0.14
# 1    [Gospel/religious, Cooking, Low Density, Female]           0.13
# 2        [Gospel/religious, Cooking, Married, Female]           0.13
# 3       [Gospel/religious, Cooking, Tertiary, Female]           0.13
# 4   [Gospel/religious, Joyful, Cooking, 101-1 000,...           0.12
# 5   [Gospel/religious, Cooking, harare, 101-1 000,...           0.10
# 6   [Gospel/religious, Joyful, Cooking, Christiani...           0.14
# 7   [Gospel/religious, Cooking, Christianity, Low ...           0.13
# 8   [Gospel/religious, Cooking, Married, Christian...           0.13
# 9   [Gospel/religious, Cooking, Tertiary, Christia...           0.13
# 10  [Gospel/religious, Cooking, Information Techno...           0.10

# %%
s=set()
import numpy as np
for i in new_df.iloc[np.arange(len(new_df)),0]:
    for j in i:
        s.add(j)
s
# Out:
# {'101-1 000',
#  'Christianity',
#  'Cooking',
#  'Female',
#  'Gospel/religious',
#  'Information Technology',
#  'Joyful',
#  'Low Density',
#  'Married',
#  'No',
#  'Tertiary',
#  'Yes',
#  'good',
#  'harare',
#  'immediate family',
#  'zimbabwe'}

# %%
'Female' in new_df.iloc[0,0]
female_list=[]
for i,rows in new_df.iterrows():
#     print(i,rows['Rules'])
    if('Female' in rows['Rules']):
        female_list.append(rows['Support_Ratio'])
#         count+=1
# data=pd.DataFrame({'Female':['female']*len(female_list),'support':female_list})
# data.head()
data={}
data['female']=female_list
data['low_density']=[rows['Support_Ratio'] for i,rows in new_df.iterrows() if('Low Density' in rows['Rules'])]

# %%
D=dict()
for j in s:
    D[j]=[rows['Support_Ratio'] for i,rows in new_df.iterrows() if(j in rows['Rules'])]
del D['No']
type(D)
# Out:
# dict

# %%
# for i in D:
#   print(i,"....",D[i])

# %%
# !pip install plotly==3.10.0

# %%
import plotly.plotly as py
import plotly.tools as tls

from matplotlib import pylab
import matplotlib.pyplot as plt
names = list(D.keys())
values = list(D.values())
width = 1 
for i in range(len(D)):
    
    pylab.bar(i,values[i],width,tick_label=names[i])
#     plt.bar(1,values[1],tick_label=names[1])
#     plt.bar(2,values[2],tick_label=names[2])
    plt.xticks(range(0,i),names,fontsize=12, rotation=30)
#plt.figure(figsize=(100,100))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylabel('Support Ratio',fontsize=14)
plt.xlabel('User Profile',fontsize=14)
plt.title('User Profile Dominance against Support Ratio',fontsize=14)
plt.savefig('association-1.png')
plt.show()

# %%
d1={'good':'Mood','Cooking':'Hobbies','Married':'Marital_Status',
   '101-1 000':'Income','Yes':'Studying/Not_Studying','Low Density':'Home_Area',
    'Tertiary':'Education_Level','harare':'City','Female':'Gender','immediate family':'Family',
   'Christianity':'Religion','zimbabwe':'Nationality','Information Technology':'Expertise',
   'Gospel/religious':'Music','Joyful':'Emotional_State'}
k=dict()
for i in d1:
  if(i in D.keys()):
    k[i]=D[i]
# dict((d1[key], value) for (key, value) in D)
D=k
# list(D.keys())

# %%
import plotly.plotly as py
import plotly.tools as tls

from matplotlib import pylab
names = list(D.keys())
values = list(D.values())
width = 1 
for i in range(len(D)):
    
    pylab.bar(i,values[i],width,tick_label=names[i])
#     plt.bar(1,values[1],tick_label=names[1])
#     plt.bar(2,values[2],tick_label=names[2])
    plt.xticks(range(0,i),names,fontsize=12,rotation=30)
#plt.figure(figsize=(100,100))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylabel('Support Ratio',fontsize=14)
plt.xlabel('User Contexts',fontsize=14)
plt.title('User Profile Dominance against Support Ratio',fontsize=14)
plt.savefig('association-2.png')
plt.show()

# %%
L=[]
# for i in range(0,len(MB)):
#     L.append(MB[2][2][0][2])
for i in range(0,len(MB)):
    L.append(MB[i][2][0][2])
d=pd.DataFrame({'Rules':listRules,'Confidence':L})
d.head(11)
# Out:
#                                                 Rules  Confidence
# 0         [Joyful, Gospel/religious, Female, Cooking]    0.875000
# 1    [Low Density, Female, Cooking, Gospel/religious]    0.928571
# 2        [Married, Female, Cooking, Gospel/religious]    0.928571
# 3       [Gospel/religious, Female, Tertiary, Cooking]    0.928571
# 4   [Joyful, Female, Gospel/religious, Cooking, 10...    0.923077
# 5   [Female, Gospel/religious, harare, Cooking, 10...    0.909091
# 6   [Joyful, Female, Gospel/religious, Christianit...    0.875000
# 7   [Female, Gospel/religious, Christianity, Cooki...    0.928571
# 8   [Married, Female, Gospel/religious, Christiani...    0.928571
# 9   [Female, Gospel/religious, Christianity, Terti...    0.928571
# 10  [Female, Gospel/religious, Cooking, Low Densit...    0.909091

# %%
s=set()
import numpy as np
for i in d.iloc[np.arange(len(d)),0]:
    for j in i:
        s.add(j)

# %%
D={}
for j in s:
    D[j]=[rows['Confidence'] for i,rows in d.iterrows() if(j in rows['Rules'])]
del D['No']

# %%
d1={'good':'Mood','Cooking':'Hobbies','Married':'Marital_Status',
   '101-1 000':'Income','Yes':'Studying/Not_Studying','Low Density':'Home_Area',
    'Tertiary':'Education_Level','harare':'City','Female':'Gender','immediate family':'Family',
   'Christianity':'Religion','zimbabwe':'Nationality','Information Technology':'Expertise',
   'Gospel/religious':'Music','Joyful':'Emotional_State'}
k=dict()
for i in d1:
  if(i in D.keys()):
    k[i]=D[i]
# dict((d1[key], value) for (key, value) in D)
D=k

# %%
import plotly.plotly as py
import plotly.tools as tls

from matplotlib import pylab
names = list(D.keys())
values = list(D.values())
width = 1 
for i in range(len(D)):
    
    pylab.bar(i,values[i],width,tick_label=names[i])
#     plt.bar(1,values[1],tick_label=names[1])
#     plt.bar(2,values[2],tick_label=names[2])
    plt.xticks(range(0,i),names,fontsize=12,rotation=30)
#plt.figure(figsize=(100,100))
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.ylabel('Confidence Values(Factors)',fontsize=14)
plt.xlabel('User Contexts',fontsize=14)
plt.title('User Profile Dominance against Confidence Value',fontsize=14)
plt.savefig('Confidence.png')
plt.show()

# %%
#Significant parameters[Family setup,gender, religion, mood, hobbies, music]
